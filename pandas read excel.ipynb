# %%
import pandas as pd
#path = "D:\\M Tech\\Internship\\Yoshops\\review_dataset.csv"
df = pd.read_excel("Project_list.xlsx")
df.head()
# Out:
#    Se. No.                                        Description  Remarks  \
# 0        1  AI recommendation based on the students health...      NaN
# 1        2  Facial expression, voice, tone, pitch recognet...      NaN
# 2        3  Personality Prediction System via CV, voice, s...      NaN
# 3        4                   Heart Disease Prediction Project      NaN
# 4        5           Identify human emotions through pictures      NaN
#
#                                                    3  \
# 0  maintain the 50 health parameters record and p...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    4  \
# 0  As of now, no one is maintain the 50 health pa...
# 1                                                NaN
# ...
