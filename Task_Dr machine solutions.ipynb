# %%
# main libraries
import pandas as pd
import numpy as np
#import time
# visual libraries
from matplotlib import pyplot as plt
import seaborn as sns
#from mpl_toolkits.mplot3d import Axes3D 
#plt.style.use('ggplot')
# sklearn libraries
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import normalize
#from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef,classification_report,roc_curve
#from sklearn.externals import joblib
#from sklearn.preprocessing import StandardScaler
#from sklearn.decomposition import PCA

# %%
df = pd.read_csv('D:\M Tech\Internship\DrMachine Solutions Private Limited\exercise_task\exercise_task\student_records.csv')
df.head()
# Out:
#    S.No Gender  Score_Football_Question  Total_Examination_Score
# 0     1      M                        1                       80
# 1     2      M                        0                       90
# 2     3      M                        0                       60
# 3     4      M                        1                       65
# 4     5      F                        0                       80

# %%
df.shape
# Out:
# (30, 4)

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
correlation_matrix = df.corr()
fig = plt.figure(figsize=(12,9))
sns.heatmap(correlation_matrix,vmax=0.9,square = True)
plt.show()

# %%
sns.pairplot(data=df[['Gender' ,'Score_Football_Question','Total_Examination_Score']], hue='Gender', dropna=True, height=5)

# %% [markdown]
# # we can say that the girls are better in score and also about the knowledge of fooltball

# %%
sns.pairplot(df, hue="Gender", diag_kind="hist")
